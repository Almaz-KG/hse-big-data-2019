# %% [markdown]
# # Last name:                   Name:                                   Group:

# %% [markdown]
# # (max 4) Part 1. Getting and Knowing your Data

# %% [markdown]
# ### (max 1) Step 1.1. Import the necessary libraries

# %% [markdown]
# ### (max 1) Step 1.2. Assign dataset (!!! file chipolte.tsv is  used) to a variable called chipo.

# %% [markdown]
# ### (max 1) Step 1.3. How many items were ordered?

# %% [markdown]
# ### (max 1) Step 1.4. How much was the revenue for the period in the dataset?

# %% [markdown]
# # (max 6) Part 2. Filtering and Sorting Data

# %% [markdown]
# ### (max 1) Step 2.1. What was the quantity of the most expensive item ordered?

# %% [markdown]
# ### (max 1) Step 2.2. How many times were a Veggie Salad Bowl ordered?

# %% [markdown]
# ### (max 1) Step 2.3. Assign new!!! dataset (!!! file Team.csv is  used) to a variable called euro12.

# %% [markdown]
# ### (max 1) Step 2.4. Present only the Shooting Accuracy from England, Italy and Russia

# %% [markdown]
# ### (max 1) Step 2.5. Select the teams that start with G

# %% [markdown]
# ### (max 1) Step 2.6. Calculate the mean Yellow Cards given per Team
