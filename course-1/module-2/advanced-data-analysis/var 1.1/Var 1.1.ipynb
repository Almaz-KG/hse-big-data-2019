# %% [markdown]
# # Last name:   Murzabekov Name: Almaz                       Group: MBD191

# %% [raw]
# # (max 4) Part 1. Getting and Knowing your Data

# %% [markdown]
# ### (max 1) Step 1.1 Import the necessary libraries

# %% [markdown]
# ### (max 1) Step 1.2. Assign dataset (!!! file u.user is used) to a variable called users and use the 'user_id' as index

# %% [markdown]
# ### (max 1) Step 1.3. What is the mean age of users?

# %% [markdown]
# ### (max 1) Step 1.4. What is the most frequent occupation?

# %% [markdown]
# # (max 6) Part 2. Filtering and Sorting Data

# %% [markdown]
# ### (max 1) Step 2.1. Assign new!!! dataset (!!! file Team.csv is  used) to a variable called euro12.

# %% [markdown]
# ### (max 1) Step 2.2. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %% [markdown]
# ### (max 1) Step 2.3. Present only the Shooting Accuracy from England, Italy and Russia

# %% [markdown]
# ### (max 1) Step 2.4. Select the teams that start with G

# %% [markdown]
# ### (max 1) Step 2.5. Calculate the mean Yellow Cards given per Team

# %% [markdown]
# ### (max 1) Step 2.6. How many team participated in the Euro2012?
